# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time


BASE_URL = "https://www.yellowpages.com/search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"
}

# List to store scraped data
data = []

# Function to scrape a single page
def scrape_page(page_url):
    try:
        response = requests.get(page_url, headers=HEADERS)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, "html.parser")
        companies = soup.find_all("div", class_="result")

        for company in companies:
            company_name = company.find("a", class_="business-name").text.strip() if company.find("a", class_="business-name") else None
            website_url = company.find("a", class_="track-visit-website")['href'] if company.find("a", class_="track-visit-website") else None
            contact_number = company.find("div", class_="phones phone primary").text.strip() if company.find("div", class_="phones phone primary") else None
            address = company.find("div", class_="street-address").text.strip() if company.find("div", class_="street-address") else None
            industry = company.find("div", class_="categories").text.strip() if company.find("div", class_="categories") else None
            description = company.find("p", class_="snippet").text.strip() if company.find("p", class_="snippet") else None
            email = None  # Emails are often not available in such directories and require further processing.

            data.append({
                "Company Name": company_name,
                "Website URL": website_url,
                "Contact Number": contact_number,
                "Location/Address": address,
                "Industry/Category": industry,
                "Company Description": description,
                "Email Address": email
            })

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page: {e}")

# Loop through the first 2-3 pages
for page in range(1, 4):
    page_url = f"{BASE_URL}&page={page}"
    print(f"Scraping page {page}")
    scrape_page(page_url)
    time.sleep(2)  # To avoid getting blocked

# Save data to CSV
df = pd.DataFrame(data)
df.to_csv("companies_data.csv", index=False, encoding="utf-8")
print("Data saved to companies_data.csv")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.yellowpages.com:443
# 2024-11-06 07:10:43 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.yellowpages.com:443
# Scraping page 1
# DEBUG:urllib3.connectionpool:https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=1 HTTP/11" 200 None
# 2024-11-06 07:10:45 [urllib3.connectionpool] DEBUG: https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=1 HTTP/11" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.yellowpages.com:443
# 2024-11-06 07:10:47 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.yellowpages.com:443
# Scraping page 2
# DEBUG:urllib3.connectionpool:https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=2 HTTP/11" 200 None
# 2024-11-06 07:10:49 [urllib3.connectionpool] DEBUG: https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=2 HTTP/11" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.yellowpages.com:443
# 2024-11-06 07:10:52 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): www.yellowpages.com:443
# Scraping page 3
# DEBUG:urllib3.connectionpool:https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=3 HTTP/11" 200 None
# 2024-11-06 07:10:54 [urllib3.connectionpool] DEBUG: https://www.yellowpages.com:443 "GET /search?search_terms=IT+Services&geo_location_terms=New+York%2C+NY&page=3 HTTP/11" 200 None
# Data saved to companies_data.csv

# %%
df = pd.read_csv('companies_data.csv')
df.head()
# Out:
#                   Company Name Website URL  Contact Number Location/Address  \
# 0                Geeks On Site         NaN             NaN              NaN
# 1  AAA All Voice And Data Inc.         NaN             NaN              NaN
# 2            My Computer Works         NaN  (800) 262-2219              NaN
# 3                Geeks On Site         NaN  (800) 531-2349              NaN
# 4            My Computer Works         NaN  (877) 201-0623              NaN
#
#                                    Industry/Category  Company Description  \
# 0    Computers & Computer Equipment-Service & Repair                  NaN
# 1  Computer Cable & Wire InstallationComputer Sys...                  NaN
# 2  Computer Service & Repair-BusinessComputer Tec...                  NaN
# 3    Computers & Computer Equipment-Service & Repair                  NaN
# 4    Computers & Computer Equipment-Service & Repair                  NaN
#
#    Email Address
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                                          Company Name  \
# 0                                       Geeks On Site
# 1                         AAA All Voice And Data Inc.
# 2                                   My Computer Works
# 3                                       Geeks On Site
# 4                                   My Computer Works
# 5                                       Geeks on Site
# 6                         AAA All Voice And Data Inc.
# 7                           Jean Martin Insurance Inc
# 8                                        EgeekPRO INC
# 9                            SourceCom Communications
# 10                                 Computer Overhauls
# 11                   New York Computer Help - Midtown
# 12                     TecProtocol Business Solutions
# 13                               ABC Computer Service
# 14                                      Computer Guys
# 15                              Jay Shapiro Computers
# 16                  Thirty5Tech - NYC Computer Repair
# 17                               NY Citi Technologies
# 18                     NyITTech - Computer Repair NYC
# 19                                   Mike's Tech Shop
# 20                                           Link Sys
# 21                                        b4computers
# 22                                             JoeNYC
# 23                                         Invenio IT
# 24                         NYC Data Recovery Services
# 25                                              NIMAX
# 26  YaFix, Apple iPhone, iPad, iPod, & Macbook Repair
# 27                                 Ramp Up Technology
# 28                                  City Tech Wizards
# 29         Computer Integrated Services Company of Ny
# 30                                          Pc Doctor
# 31                                       Sentril Tech
# 32                                      iFix New York
# 33                      Daniel Express Communications
# 34                                     PSOFNTECH, INC
# 35                                      Icompunet Inc
# 36                                        TriStateTek
# 37                                    Technology Pros
# 38                                 Little Laptop Shop
# 39                                 D & Q Computer Inc
# 40                                  Mac Concierge Inc
# 41                                         Pure Logic
# 42                                         Mac Hattan
# 43                                Computer Repair NYC
# 44                                Precision Discovery
# 45                                   3 H Technologies
# 46                               My Computer Tech Inc
# 47                                      Computer Guys
# 48                             Hitec Computer Repairs
# 49                          Sotis Business Technology
# 50                                     Nerd On Demand
# 51                                          Pinnadyne
# 52                                             Aspeed
# 53                       Techknowsphere Solutions Inc
# 54                       Asap Computer Repair Service
# 55                 Advanced Computer Technologies Inc
# 56                           877TECH Of New York City
# 57                                          Bion Tech
# 58                                      Geek National
# 59                                             Ibmtss
# 60                     Computer Repair - Geeks Mobile
# 61                                        Ng Tech Inc
# 62                                  Computer Hospital
# 63                                        Geek Choice
# 64                  Corporate Innovation Technologies
# 65                           Miracle Technologies Inc
# 66                                 Integrate New York
# 67                                          Mac PC NY
# 68                                   GreenTech Expert
# 69                                        Hello Nerds
# 70                                           Tecniquo
# 71      Hi-Tech Electronics Camera and Macbook Repair
# 72                                Apple Grand Central
# 73                                          SpeedGeek
# 74                                     Cyber Security
# 75                                       NY City Geek
# 76                                Digital Repairs NYC
# 77                           Computer Troubleshooters
# 78                 Offshore Computing Service Limited
# 79                        Apple Berry Parts Inc 57 St
# 80                                     SGU Consulting
# 81                                          Brealcorp
# 82                                        Data Vision
# 83                LaptopMD - Computer & iPhone Repair
# 84                                         Geek Squad
# 85                                   Atomic Bytes Inc
# 86                         American Copy Machine LTD.
# 87                                          Cybercity
# 88                       Global Data Publications Inc
# 89                      New York Computer Help - SOHO
# 90                                      Promethean IT
# 91                                 Tech Support 4 NYC
#
#                                           Website URL  Contact Number  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN  (800) 262-2219
# 3                                                 NaN  (800) 531-2349
# 4                                                 NaN  (877) 201-0623
# 5                                                 NaN  (877) 223-4607
# 6   https://api.superpages.com/xml/search?SRC=ypin...  (646) 921-7849
# 7             https://www.jeanmartin.com/contact.html  (833) 277-0597
# 8                                                 NaN  (212) 388-5943
# 9                                                 NaN  (844) 768-7240
# 10                   http://www.computeroverhauls.com  (212) 216-9711
# 11                 http://www.newyorkcomputerhelp.com  (212) 599-0339
# 12                         http://www.tecprotocol.com  (212) 500-6644
# 13                     http://abccomputerservices.com  (212) 725-3511
# 14                                                NaN  (212) 414-0321
# 15        https://www.jayshapirocomputers.com/contact  (877) 747-1711
# 16                         http://www.thirty5tech.com  (917) 508-6047
# 17                                                NaN  (917) 267-9816
# 18                                                NaN  (718) 360-2750
# 19                       http://www.mikestechshop.com  (212) 924-6453
# 20                                                NaN  (646) 370-1963
# 21                         http://www.b4computers.com  (718) 675-4069
# 22                              http://www.joenyc.com  (212) 777-2986
# 23                               http://invenioit.com  (646) 395-1170
# 24                   http://www.datarecoverynycny.com  (212) 729-6594
# 25                             http://www.gonimax.com  (347) 788-0122
# 26                 http://www.flickr.com/photos/yafix  (347) 669-2349
# 27                                                NaN  (212) 633-0656
# 28                     http://www.citytechwizards.com  (646) 820-4369
# 29                              https://www.cisus.com  (212) 577-6033
# 30                                                NaN  (917) 399-1794
# 31                                                NaN  (646) 283-9667
# 32                              http://www.ifixny.com  (212) 933-4440
# 33                           http://danielexpress.com  (212) 877-2200
# 34                           http://www.psofntech.com  (212) 740-1300
# 35                           http://www.icompunet.com  (212) 461-1019
# 36                                                NaN  (212) 748-9290
# 37                                                NaN  (800) 778-5331
# 38                    http://www.littlelaptopshop.com  (212) 674-3111
# 39               http://www.dandqcomputer.com/contact  (212) 260-8236
# 40                        http://www.macconcierge.com  (212) 533-8222
# 41                           http://www.purelogic.com  (212) 675-9800
# 42                               http://machattan.com  (212) 242-9393
# 43                       http://www.audiovideonyc.com  (212) 729-4305
# 44                      http://precisiondiscovery.com  (212) 292-1161
# 45                               http://www.apple.com  (212) 588-8760
# 46                   http://www.mycomputertechinc.com  (212) 828-1600
# 47                                                NaN  (212) 288-2416
# 48                                                NaN  (212) 374-1008
# 49                                                NaN  (646) 289-5902
# 50                            http://nerdondemand.com  (646) 801-6373
# 51                           http://www.pinnadyne.com  (877) 851-5250
# 52                                                NaN  (646) 633-4900
# 53                               http://transbeam.com  (212) 391-1570
# 54                                                NaN  (347) 705-7369
# 55                              http://www.actweb.com  (212) 764-6430
# 56                                                NaN  (646) 553-1618
# 57                                http://biontech.com  (516) 596-5443
# 58                                   http://gicny.com  (212) 488-0001
# 59                                                NaN  (212) 572-2900
# 60                                                NaN  (718) 360-9369
# 61                                                NaN  (212) 396-2088
# 62                      https://computer-hospital.com  (212) 568-6767
# 63                 http://www.geekchoice.com/New-York  (212) 564-7500
# 64                                                NaN  (212) 498-9992
# 65                       https://www.miracletechs.com  (646) 237-4472
# 66                                                NaN  (855) 254-4396
# 67                                                NaN  (212) 991-8240
# 68                                                NaN  (917) 497-7023
# 69                          https://www.hellonerds.ca  (888) 878-0593
# 70                                                NaN  (800) 562-5648
# 71                           http://www.newhitech.net  (212) 219-3794
# 72  https://www.apple.com/retail/grandcentral?cid=...  (212) 284-1800
# 73                           http://www.speedgeek.com  (212) 641-0008
# 74                           http://www.aspiretss.com  (917) 600-9233
# 75                                                NaN  (212) 537-6835
# 76                                                NaN  (917) 946-6487
# 77                           http://www.comptroub.com  (212) 686-1234
# 78                                                NaN  (212) 709-8338
# 79                                                NaN  (212) 581-0600
# 80                       http://www.sguconsulting.com  (212) 380-1333
# 81                                                NaN  (917) 677-9810
# 82                             http://www.datavis.com  (212) 689-1111
# 83                            http://www.laptopmd.com  (212) 920-4833
# 84                           http://www.geeksquad.com  (800) 371-6275
# 85          https://sherlockdatarecovery.com/location  (212) 249-9888
# 86                http://www.americancopymachines.com  (212) 244-2727
# 87                          https://www.cybercity.nyc  (212) 633-0649
# 88              https://www.globaldata.com/contact-us  (646) 395-5460
# 89                https://www.newyorkcomputerhelp.com  (212) 599-0339
# 90                                                NaN  (212) 226-6686
# 91                     http://www.techsupport4nyc.com  (877) 467-4989
#
#                  Location/Address  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6             303 Avenue P Apt F7
# 7      551 5Th Avenue, Suite 1425
# 8                     42 Broadway
# 9                 275 Madison Ave
# 10             7 Penn Plz Ste 749
# 11        53 E 34th St, 3rd Floor
# 12      353 W 48th St, Suite# 454
# 13            15 E 40th St Rm 903
# 14                   18 E 16th St
# 15                   1313 3rd Ave
# 16  35 Fort Washington Ave Apt 3c
# 17               On-Site Services
# 18                  360 W 57th St
# 19                  120 W 20th St
# 20           303 W 42nd St Ste 52
# 21                   28 Warren ST
# 22       77 Bleecker St Apt C2-21
# 23                  122 W 26th St
# 24                 373 Park Ave S
# 25             234 5th Ave Fl 405
# 26                    349 5th Ave
# 27                  108 W 39th St
# 28          325 W 38th St Rm 1105
# 29                   12 E 44th St
# 30                   645 12th Ave
# 31           445 E 65th St Apt 6b
# 32                  247 E 77th St
# 33              495 Amsterdam Ave
# 34        1221 Saint Nicholas Ave
# 35           75 Maiden Ln Ste 335
# 36          248 W 35th St Rm 1206
# 37                   20 W 44th St
# 38                   7 Clinton St
# 39                   206 Avenue B
# 40                   55 W 21st St
# 41                  148 W 24th St
# 42                  249 W 34th St
# 43                    519 8th Ave
# 44           25 W 45th St Ste 701
# 45            1173 2nd Ave Frnt 1
# 46                  400 E 87th St
# 47           229 E 84th St Frnt 2
# 48                   108 Duane St
# 49                  79 Leonard St
# 50                    96 Cedar St
# 51                    30 Broad St
# 52                     1 Penn Plz
# 53                   20 W 36th St
# 54           445 9th Ave # 900216
# 55                   200 Park Ave
# 56               845 3rd Ave Fl 6
# 57              641 Lexington Ave
# 58                   410 Park Ave
# 59                    909 3rd Ave
# 60                  310 W 72nd St
# 61                  217 E 85th St
# 62             2087 Amsterdam Ave
# 63                 243 W Broadway
# 64                  10 East 40 St
# 65                     30 Wall St
# 66          110 W 40th St Rm 1004
# 67                       7 Dey St
# 68                            NaN
# 69             77 Water St 7th Fl
# 70                   41 River Ter
# 71                    47 Canal st
# 72      45 Grand Central Terminal
# 73                20 Vesey Street
# 74              380 Lexington Ave
# 75                    666 3rd Ave
# 76                    736 7th Ave
# 77                132 Madison Ave
# 78                     67 Wall St
# 79                  205 W 57th St
# 80                 110 W 140th St
# 81                            NaN
# 82                  225 W 39th St
# 83     247 West 38th Street, #602
# 84                    529 5th Ave
# 85                  500 E 87th St
# 86            141 W 28th St Fl 10
# 87                  224 W 30th St
# 88              441 Lexington Ave
# 89            110 Greene St Fl 11
# 90                 65 Bleecker St
# 91     900 Avenue Of The Americas
#
#                                     Industry/Category  Company Description  \
# 0     Computers & Computer Equipment-Service & Repair                  NaN
# 1   Computer Cable & Wire InstallationComputer Sys...                  NaN
# 2   Computer Service & Repair-BusinessComputer Tec...                  NaN
# 3     Computers & Computer Equipment-Service & Repair                  NaN
# 4     Computers & Computer Equipment-Service & Repair                  NaN
# 5   Computer Software & ServicesComputer Printers ...                  NaN
# 6   Telecommunications ConsultantsComputer Network...                  NaN
# 7   Concrete ContractorsComputer Technical Assista...                  NaN
# 8   Computers & Computer Equipment-Service & Repai...                  NaN
# 9   Utility CompaniesTelephone CompaniesComputers ...                  NaN
# 10  Computer & Equipment DealersConsumer Electroni...                  NaN
# 11  Computers & Computer Equipment-Service & Repai...                  NaN
# 12  Computer Software & ServicesCopiers & Supplies...                  NaN
# 13  Computer Service & Repair-BusinessComputers & ...                  NaN
# 14  Computer Service & Repair-BusinessComputer & E...                  NaN
# 15  Computer Software & ServicesMachine ShopsMachi...                  NaN
# 16  Computer Technical Assistance & Support Servic...                  NaN
# 17  Computer System Designers & ConsultantsCompute...                  NaN
# 18  Computer Data RecoveryComputer Online Services...                  NaN
# 19  Computers & Computer Equipment-Service & Repai...                  NaN
# 20  Mobile Home Equipment & PartsMobile Home Repai...                  NaN
# 21  Computer System Designers & ConsultantsCompute...                  NaN
# 22  Computer Network Design & SystemsComputer Syst...                  NaN
# 23  Computer & Equipment DealersComputer Printers ...                  NaN
# 24  Computer Service & Repair-BusinessComputers & ...                  NaN
# 25  Computer Data RecoveryComputer Online Services...                  NaN
# 26  Cellular Telephone ServiceComputers & Computer...                  NaN
# 27  Computer Online ServicesComputer Software & Se...                  NaN
# 28  Computer Online ServicesComputer Software & Se...                  NaN
# 29  Computer Network Design & SystemsComputer Syst...                  NaN
# 30  Computer Online ServicesComputer Software & Se...                  NaN
# 31    Computers & Computer Equipment-Service & Repair                  NaN
# 32  Computer Data RecoveryCellular Telephone Equip...                  NaN
# 33  Consumer ElectronicsCellular Telephone Equipme...                  NaN
# 34  Computer Online ServicesGraphic DesignersCompu...                  NaN
# 35  Computer Service & Repair-BusinessComputers & ...                  NaN
# 36  Computer Data RecoveryComputer Service & Repai...                  NaN
# 37  Computer Data RecoveryComputer Service & Repai...                  NaN
# 38  Computer Service & Repair-BusinessComputer & E...                  NaN
# 39    Computers & Computer Equipment-Service & Repair                  NaN
# 40  Computer Network Design & SystemsComputer Data...                  NaN
# 41    Computers & Computer Equipment-Service & Repair                  NaN
# 42  Computer & Equipment DealersComputers & Comput...                  NaN
# 43  Computer & Equipment Renting & LeasingComputer...                  NaN
# 44  Computer & Equipment DealersComputers & Comput...                  NaN
# 45  Computer Network Design & SystemsComputer & Eq...                  NaN
# 46  Computer Service & Repair-BusinessComputer & E...                  NaN
# 47  Computers & Computer Equipment-Service & Repai...                  NaN
# 48    Computers & Computer Equipment-Service & Repair                  NaN
# 49  Computers & Computer Equipment-Service & Repai...                  NaN
# 50  Computer Network Design & SystemsComputer Serv...                  NaN
# 51  Computer Network Design & SystemsComputer Onli...                  NaN
# 52  Computers & Computer Equipment-Service & Repai...                  NaN
# 53    Computers & Computer Equipment-Service & Repair                  NaN
# 54  Computer Service & Repair-BusinessComputers & ...                  NaN
# 55  Computer & Equipment DealersComputers & Comput...                  NaN
# 56    Computers & Computer Equipment-Service & Repair                  NaN
# 57  Computers & Computer Equipment-Service & Repai...                  NaN
# 58  Computers & Computer Equipment-Service & Repai...                  NaN
# 59  Computer-Wholesale & ManufacturersComputers & ...                  NaN
# 60  Computers & Computer Equipment-Service & Repai...                  NaN
# 61    Computers & Computer Equipment-Service & Repair                  NaN
# 62  Computer Service & Repair-BusinessComputers & ...                  NaN
# 63    Computers & Computer Equipment-Service & Repair                  NaN
# 64  Computer Network Design & SystemsComputer Soft...                  NaN
# 65  Computer Network Design & SystemsComputers & C...                  NaN
# 66   Computer Technical Assistance & Support Services                  NaN
# 67  Computer Software & ServicesComputer Service &...                  NaN
# 68  Computer Technical Assistance & Support Servic...                  NaN
# 69  Computer Technical Assistance & Support Servic...                  NaN
# 70  Computer Cable & Wire InstallationComputer Net...                  NaN
# 71  Television & Radio-Service & RepairElectronic ...                  NaN
# 72  Consumer ElectronicsComputers & Computer Equip...                  NaN
# 73  Computer Technical Assistance & Support Servic...                  NaN
# 74  Computer Technical Assistance & Support Servic...                  NaN
# 75  Computer Service & Repair-BusinessComputers & ...                  NaN
# 76  Electronic Equipment & Supplies-Repair & Servi...                  NaN
# 77  Computers & Computer Equipment-Service & Repai...                  NaN
# 78   Computer Technical Assistance & Support Services                  NaN
# 79  Computers & Computer Equipment-Service & Repai...                  NaN
# 80  Computers & Computer Equipment-Service & Repai...                  NaN
# 81  Computer Cable & Wire InstallationComputer Net...                  NaN
# 82  Computers & Computer Equipment-Service & Repai...                  NaN
# 83  Computer Data RecoveryComputer Technical Assis...                  NaN
# 84  Computers & Computer Equipment-Service & Repai...                  NaN
# 85  Computer Data RecoveryComputer Network Design ...                  NaN
# 86  Copy Machines & SuppliesComputers & Computer E...                  NaN
# 87  Computers & Computer Equipment-Service & Repai...                  NaN
# 88  Computer Technical Assistance & Support Servic...                  NaN
# 89  Computers & Computer Equipment-Service & Repai...                  NaN
# 90  Computer Security-Systems & ServicesComputer S...                  NaN
# 91  Computer Network Design & SystemsComputer Serv...                  NaN
#
#     Email Address
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
# 50            NaN
# 51            NaN
# 52            NaN
# 53            NaN
# 54            NaN
# 55            NaN
# 56            NaN
# 57            NaN
# 58            NaN
# 59            NaN
# 60            NaN
# 61            NaN
# 62            NaN
# 63            NaN
# 64            NaN
# 65            NaN
# 66            NaN
# 67            NaN
# 68            NaN
# 69            NaN
# 70            NaN
# 71            NaN
# 72            NaN
# 73            NaN
# 74            NaN
# 75            NaN
# 76            NaN
# 77            NaN
# 78            NaN
# 79            NaN
# 80            NaN
# 81            NaN
# 82            NaN
# 83            NaN
# 84            NaN
# 85            NaN
# 86            NaN
# 87            NaN
# 88            NaN
# 89            NaN
# 90            NaN
# 91            NaN
